# %%
import pandas as pd
weights = pd.read_csv("weights.csv")
len(weights)
weights
# Out:
#     COLOR          W1          W2            W3          W4          W5
# 0       B  500.000404  249.999296  5.000000e+07  199.999230  199.999230
# 1       R  497.415249  254.199715  5.000000e+07  208.864867  208.864867
# 2       G  497.706185  254.795972  5.000000e+07  205.273197  205.273197
# 3       B  500.000561  249.998981  5.000000e+07  199.998896  199.998896
# 4       R  496.382922  256.750418  5.000000e+07  210.414973  210.414973
# 5       G  496.305351  257.011751  5.000000e+07  209.837607  209.837607
# 6       B  500.000780  249.998677  5.000000e+07  199.998534  199.998534
# 7       R  495.493068  260.585121  5.000000e+07  212.518120  212.518120
# 8       G  495.053981  260.214150  5.000000e+07  213.499933  213.499933
# 9       B  499.578142  249.469095  5.000000e+07  200.057878  200.057878
# 10      R  494.785235  262.494015  5.000000e+07  214.989279  214.989279
# 11      G  493.847830  261.557474  5.000000e+07  218.209932  218.209932
# ...

# %%
versions = []
version = 1

for i in range(int(len(weights)/3)):
    for j in range(3):
        versions.append(version)
    version+=1
weights["version"] = versions
weights
# Out:
#     COLOR          W1          W2            W3          W4          W5  \
# 0       B  500.000404  249.999296  5.000000e+07  199.999230  199.999230
# 1       R  497.415249  254.199715  5.000000e+07  208.864867  208.864867
# 2       G  497.706185  254.795972  5.000000e+07  205.273197  205.273197
# 3       B  500.000561  249.998981  5.000000e+07  199.998896  199.998896
# 4       R  496.382922  256.750418  5.000000e+07  210.414973  210.414973
# 5       G  496.305351  257.011751  5.000000e+07  209.837607  209.837607
# 6       B  500.000780  249.998677  5.000000e+07  199.998534  199.998534
# 7       R  495.493068  260.585121  5.000000e+07  212.518120  212.518120
# 8       G  495.053981  260.214150  5.000000e+07  213.499933  213.499933
# 9       B  499.578142  249.469095  5.000000e+07  200.057878  200.057878
# 10      R  494.785235  262.494015  5.000000e+07  214.989279  214.989279
# 11      G  493.847830  261.557474  5.000000e+07  218.209932  218.209932
# ...

# %%
export_csv = weights.to_csv ('weight_versions.csv', index = None, header=True)
